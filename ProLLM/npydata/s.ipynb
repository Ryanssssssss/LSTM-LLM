# %%
import numpy as np

# 读取npy文件
file_path = "/home/wuwujian/LXY/sensor_process/seedLLM/npydata/con1con1Sensor/con1con1Sensor_test_y.npy"
try:
    labels = np.load(file_path)
except FileNotFoundError:
    print(f"错误：未找到文件 {file_path}")
    exit(1)
except Exception as e:
    print(f"读取文件出错：{e}")
    exit(1)

# 确保标签是一维数组（通常标签应为一维）
if labels.ndim != 1:
    print(f"警告：标签数组维度为 {labels.ndim}，将尝试展平为一维")
    labels = labels.flatten()

# 获取总样本数和唯一类别
total_samples = len(labels)
unique_classes = np.unique(labels)
print(f"总样本数：{total_samples}")
print(f"唯一类别：{unique_classes}\n")

# 检查是否按类别分块排序
current_class = labels[0]
block_start = 0
blocks = []  # 存储每个块的信息 (类别, 起始索引, 结束索引)
is_block_sorted = True

for i in range(1, total_samples):
    if labels[i] != current_class:
        # 记录当前块
        blocks.append((current_class, block_start, i-1))
        # 检查后续是否还有之前的类别出现（如果有则说明不是分块排序）
        if current_class in labels[i:]:
            is_block_sorted = False
        # 更新当前类别和起始索引
        current_class = labels[i]
        block_start = i

# 记录最后一个块
blocks.append((current_class, block_start, total_samples-1))

# 输出结果
print("类别块信息（类别, 起始索引, 结束索引）：")
for idx, (cls, start, end) in enumerate(blocks):
    print(f"块 {idx+1}: 类别={cls}, 范围=[{start}, {end}], 样本数={end - start + 1}")

print(f"\n是否按类别分块排序：{'是' if is_block_sorted else '否'}")

if not is_block_sorted:
    print("提示：存在类别在多个块中出现（非连续分块）")
# Out:
# 总样本数：480
# 唯一类别：[1 2 3 4]
#
# 类别块信息（类别, 起始索引, 结束索引）：
# 块 1: 类别=4, 范围=[0, 0], 样本数=1
# 块 2: 类别=2, 范围=[1, 2], 样本数=2
# 块 3: 类别=4, 范围=[3, 4], 样本数=2
# 块 4: 类别=2, 范围=[5, 5], 样本数=1
# 块 5: 类别=1, 范围=[6, 6], 样本数=1
# 块 6: 类别=2, 范围=[7, 7], 样本数=1
# 块 7: 类别=1, 范围=[8, 8], 样本数=1
# 块 8: 类别=4, 范围=[9, 9], 样本数=1
# 块 9: 类别=3, 范围=[10, 10], 样本数=1
# 块 10: 类别=1, 范围=[11, 12], 样本数=2
# 块 11: 类别=4, 范围=[13, 13], 样本数=1
# 块 12: 类别=3, 范围=[14, 15], 样本数=2
# 块 13: 类别=1, 范围=[16, 16], 样本数=1
# 块 14: 类别=2, 范围=[17, 17], 样本数=1
# 块 15: 类别=4, 范围=[18, 20], 样本数=3
# 块 16: 类别=1, 范围=[21, 21], 样本数=1
# 块 17: 类别=4, 范围=[22, 22], 样本数=1
# 块 18: 类别=2, 范围=[23, 23], 样本数=1
# 块 19: 类别=4, 范围=[24, 24], 样本数=1
# 块 20: 类别=1, 范围=[25, 26], 样本数=2
# 块 21: 类别=3, 范围=[27, 27], 样本数=1
# 块 22: 类别=4, 范围=[28, 28], 样本数=1
# 块 23: 类别=1, 范围=[29, 29], 样本数=1
# 块 24: 类别=3, 范围=[30, 30], 样本数=1
# 块 25: 类别=1, 范围=[31, 31], 样本数=1
# 块 26: 类别=3, 范围=[32, 32], 样本数=1
# 块 27: 类别=1, 范围=[33, 33], 样本数=1
# 块 28: 类别=4, 范围=[34, 34], 样本数=1
# 块 29: 类别=3, 范围=[35, 35], 样本数=1
# 块 30: 类别=2, 范围=[36, 36], 样本数=1
# 块 31: 类别=1, 范围=[37, 38], 样本数=2
# 块 32: 类别=4, 范围=[39, 39], 样本数=1
# 块 33: 类别=3, 范围=[40, 40], 样本数=1
# 块 34: 类别=1, 范围=[41, 41], 样本数=1
# 块 35: 类别=3, 范围=[42, 43], 样本数=2
# 块 36: 类别=1, 范围=[44, 44], 样本数=1
# 块 37: 类别=4, 范围=[45, 45], 样本数=1
# 块 38: 类别=2, 范围=[46, 46], 样本数=1
# 块 39: 类别=1, 范围=[47, 47], 样本数=1
# 块 40: 类别=4, 范围=[48, 48], 样本数=1
# 块 41: 类别=3, 范围=[49, 49], 样本数=1
# 块 42: 类别=4, 范围=[50, 51], 样本数=2
# 块 43: 类别=2, 范围=[52, 54], 样本数=3
# 块 44: 类别=3, 范围=[55, 55], 样本数=1
# 块 45: 类别=1, 范围=[56, 56], 样本数=1
# 块 46: 类别=3, 范围=[57, 58], 样本数=2
# 块 47: 类别=1, 范围=[59, 59], 样本数=1
# 块 48: 类别=2, 范围=[60, 60], 样本数=1
# 块 49: 类别=1, 范围=[61, 61], 样本数=1
# 块 50: 类别=4, 范围=[62, 62], 样本数=1
# 块 51: 类别=1, 范围=[63, 63], 样本数=1
# 块 52: 类别=2, 范围=[64, 65], 样本数=2
# 块 53: 类别=1, 范围=[66, 66], 样本数=1
# 块 54: 类别=4, 范围=[67, 67], 样本数=1
# 块 55: 类别=3, 范围=[68, 69], 样本数=2
# 块 56: 类别=4, 范围=[70, 70], 样本数=1
# 块 57: 类别=3, 范围=[71, 72], 样本数=2
# 块 58: 类别=2, 范围=[73, 73], 样本数=1
# 块 59: 类别=3, 范围=[74, 74], 样本数=1
# 块 60: 类别=2, 范围=[75, 75], 样本数=1
# 块 61: 类别=1, 范围=[76, 76], 样本数=1
# 块 62: 类别=3, 范围=[77, 77], 样本数=1
# 块 63: 类别=1, 范围=[78, 78], 样本数=1
# 块 64: 类别=4, 范围=[79, 79], 样本数=1
# 块 65: 类别=2, 范围=[80, 80], 样本数=1
# 块 66: 类别=3, 范围=[81, 82], 样本数=2
# 块 67: 类别=2, 范围=[83, 83], 样本数=1
# 块 68: 类别=3, 范围=[84, 85], 样本数=2
# 块 69: 类别=4, 范围=[86, 86], 样本数=1
# 块 70: 类别=3, 范围=[87, 87], 样本数=1
# 块 71: 类别=1, 范围=[88, 88], 样本数=1
# 块 72: 类别=3, 范围=[89, 89], 样本数=1
# 块 73: 类别=2, 范围=[90, 90], 样本数=1
# 块 74: 类别=4, 范围=[91, 91], 样本数=1
# 块 75: 类别=3, 范围=[92, 92], 样本数=1
# 块 76: 类别=4, 范围=[93, 93], 样本数=1
# 块 77: 类别=2, 范围=[94, 94], 样本数=1
# 块 78: 类别=3, 范围=[95, 95], 样本数=1
# 块 79: 类别=4, 范围=[96, 96], 样本数=1
# 块 80: 类别=1, 范围=[97, 97], 样本数=1
# 块 81: 类别=3, 范围=[98, 98], 样本数=1
# 块 82: 类别=1, 范围=[99, 99], 样本数=1
# 块 83: 类别=3, 范围=[100, 100], 样本数=1
# 块 84: 类别=1, 范围=[101, 101], 样本数=1
# 块 85: 类别=4, 范围=[102, 102], 样本数=1
# 块 86: 类别=2, 范围=[103, 103], 样本数=1
# 块 87: 类别=3, 范围=[104, 105], 样本数=2
# 块 88: 类别=2, 范围=[106, 106], 样本数=1
# 块 89: 类别=3, 范围=[107, 107], 样本数=1
# 块 90: 类别=2, 范围=[108, 111], 样本数=4
# 块 91: 类别=3, 范围=[112, 113], 样本数=2
# 块 92: 类别=2, 范围=[114, 114], 样本数=1
# 块 93: 类别=3, 范围=[115, 117], 样本数=3
# 块 94: 类别=4, 范围=[118, 119], 样本数=2
# 块 95: 类别=3, 范围=[120, 120], 样本数=1
# 块 96: 类别=4, 范围=[121, 121], 样本数=1
# 块 97: 类别=1, 范围=[122, 122], 样本数=1
# 块 98: 类别=4, 范围=[123, 124], 样本数=2
# 块 99: 类别=2, 范围=[125, 125], 样本数=1
# 块 100: 类别=4, 范围=[126, 126], 样本数=1
# 块 101: 类别=1, 范围=[127, 127], 样本数=1
# 块 102: 类别=4, 范围=[128, 128], 样本数=1
# 块 103: 类别=2, 范围=[129, 129], 样本数=1
# 块 104: 类别=3, 范围=[130, 131], 样本数=2
# 块 105: 类别=4, 范围=[132, 132], 样本数=1
# 块 106: 类别=2, 范围=[133, 133], 样本数=1
# 块 107: 类别=4, 范围=[134, 134], 样本数=1
# 块 108: 类别=2, 范围=[135, 135], 样本数=1
# 块 109: 类别=1, 范围=[136, 136], 样本数=1
# 块 110: 类别=2, 范围=[137, 137], 样本数=1
# 块 111: 类别=4, 范围=[138, 138], 样本数=1
# 块 112: 类别=2, 范围=[139, 140], 样本数=2
# 块 113: 类别=3, 范围=[141, 141], 样本数=1
# 块 114: 类别=1, 范围=[142, 142], 样本数=1
# 块 115: 类别=2, 范围=[143, 143], 样本数=1
# 块 116: 类别=4, 范围=[144, 144], 样本数=1
# 块 117: 类别=3, 范围=[145, 145], 样本数=1
# 块 118: 类别=2, 范围=[146, 146], 样本数=1
# 块 119: 类别=3, 范围=[147, 147], 样本数=1
# 块 120: 类别=1, 范围=[148, 148], 样本数=1
# 块 121: 类别=3, 范围=[149, 149], 样本数=1
# 块 122: 类别=2, 范围=[150, 150], 样本数=1
# 块 123: 类别=4, 范围=[151, 151], 样本数=1
# 块 124: 类别=3, 范围=[152, 155], 样本数=4
# 块 125: 类别=4, 范围=[156, 156], 样本数=1
# 块 126: 类别=3, 范围=[157, 157], 样本数=1
# 块 127: 类别=4, 范围=[158, 158], 样本数=1
# 块 128: 类别=1, 范围=[159, 159], 样本数=1
# 块 129: 类别=4, 范围=[160, 161], 样本数=2
# 块 130: 类别=3, 范围=[162, 162], 样本数=1
# 块 131: 类别=2, 范围=[163, 163], 样本数=1
# 块 132: 类别=3, 范围=[164, 165], 样本数=2
# 块 133: 类别=2, 范围=[166, 166], 样本数=1
# 块 134: 类别=1, 范围=[167, 169], 样本数=3
# 块 135: 类别=2, 范围=[170, 170], 样本数=1
# 块 136: 类别=3, 范围=[171, 172], 样本数=2
# 块 137: 类别=2, 范围=[173, 174], 样本数=2
# 块 138: 类别=1, 范围=[175, 175], 样本数=1
# 块 139: 类别=4, 范围=[176, 176], 样本数=1
# 块 140: 类别=2, 范围=[177, 177], 样本数=1
# 块 141: 类别=1, 范围=[178, 178], 样本数=1
# 块 142: 类别=3, 范围=[179, 179], 样本数=1
# 块 143: 类别=1, 范围=[180, 180], 样本数=1
# 块 144: 类别=3, 范围=[181, 181], 样本数=1
# 块 145: 类别=4, 范围=[182, 183], 样本数=2
# 块 146: 类别=3, 范围=[184, 184], 样本数=1
# 块 147: 类别=2, 范围=[185, 185], 样本数=1
# 块 148: 类别=4, 范围=[186, 186], 样本数=1
# 块 149: 类别=2, 范围=[187, 187], 样本数=1
# 块 150: 类别=3, 范围=[188, 188], 样本数=1
# 块 151: 类别=1, 范围=[189, 190], 样本数=2
# 块 152: 类别=3, 范围=[191, 191], 样本数=1
# 块 153: 类别=2, 范围=[192, 194], 样本数=3
# 块 154: 类别=3, 范围=[195, 195], 样本数=1
# 块 155: 类别=2, 范围=[196, 196], 样本数=1
# 块 156: 类别=1, 范围=[197, 198], 样本数=2
# 块 157: 类别=4, 范围=[199, 199], 样本数=1
# 块 158: 类别=2, 范围=[200, 200], 样本数=1
# 块 159: 类别=1, 范围=[201, 201], 样本数=1
# 块 160: 类别=3, 范围=[202, 202], 样本数=1
# 块 161: 类别=2, 范围=[203, 205], 样本数=3
# 块 162: 类别=3, 范围=[206, 206], 样本数=1
# 块 163: 类别=2, 范围=[207, 207], 样本数=1
# 块 164: 类别=1, 范围=[208, 209], 样本数=2
# 块 165: 类别=2, 范围=[210, 212], 样本数=3
# 块 166: 类别=1, 范围=[213, 215], 样本数=3
# 块 167: 类别=3, 范围=[216, 216], 样本数=1
# 块 168: 类别=4, 范围=[217, 217], 样本数=1
# 块 169: 类别=3, 范围=[218, 218], 样本数=1
# 块 170: 类别=4, 范围=[219, 219], 样本数=1
# 块 171: 类别=1, 范围=[220, 220], 样本数=1
# 块 172: 类别=3, 范围=[221, 221], 样本数=1
# 块 173: 类别=1, 范围=[222, 222], 样本数=1
# 块 174: 类别=2, 范围=[223, 223], 样本数=1
# 块 175: 类别=3, 范围=[224, 224], 样本数=1
# 块 176: 类别=4, 范围=[225, 225], 样本数=1
# 块 177: 类别=3, 范围=[226, 226], 样本数=1
# 块 178: 类别=2, 范围=[227, 227], 样本数=1
# 块 179: 类别=4, 范围=[228, 228], 样本数=1
# 块 180: 类别=1, 范围=[229, 231], 样本数=3
# 块 181: 类别=2, 范围=[232, 233], 样本数=2
# 块 182: 类别=3, 范围=[234, 236], 样本数=3
# 块 183: 类别=2, 范围=[237, 237], 样本数=1
# 块 184: 类别=1, 范围=[238, 238], 样本数=1
# 块 185: 类别=2, 范围=[239, 240], 样本数=2
# 块 186: 类别=1, 范围=[241, 242], 样本数=2
# 块 187: 类别=3, 范围=[243, 243], 样本数=1
# 块 188: 类别=2, 范围=[244, 244], 样本数=1
# 块 189: 类别=4, 范围=[245, 246], 样本数=2
# 块 190: 类别=1, 范围=[247, 247], 样本数=1
# 块 191: 类别=2, 范围=[248, 248], 样本数=1
# 块 192: 类别=1, 范围=[249, 249], 样本数=1
# 块 193: 类别=2, 范围=[250, 250], 样本数=1
# 块 194: 类别=4, 范围=[251, 251], 样本数=1
# 块 195: 类别=3, 范围=[252, 252], 样本数=1
# 块 196: 类别=2, 范围=[253, 253], 样本数=1
# 块 197: 类别=4, 范围=[254, 254], 样本数=1
# 块 198: 类别=1, 范围=[255, 255], 样本数=1
# 块 199: 类别=4, 范围=[256, 256], 样本数=1
# 块 200: 类别=1, 范围=[257, 257], 样本数=1
# 块 201: 类别=3, 范围=[258, 259], 样本数=2
# 块 202: 类别=4, 范围=[260, 260], 样本数=1
# 块 203: 类别=1, 范围=[261, 261], 样本数=1
# 块 204: 类别=4, 范围=[262, 262], 样本数=1
# 块 205: 类别=2, 范围=[263, 263], 样本数=1
# 块 206: 类别=4, 范围=[264, 264], 样本数=1
# 块 207: 类别=2, 范围=[265, 265], 样本数=1
# 块 208: 类别=4, 范围=[266, 266], 样本数=1
# 块 209: 类别=2, 范围=[267, 268], 样本数=2
# 块 210: 类别=4, 范围=[269, 269], 样本数=1
# 块 211: 类别=2, 范围=[270, 270], 样本数=1
# 块 212: 类别=1, 范围=[271, 272], 样本数=2
# 块 213: 类别=3, 范围=[273, 275], 样本数=3
# 块 214: 类别=2, 范围=[276, 276], 样本数=1
# 块 215: 类别=4, 范围=[277, 277], 样本数=1
# 块 216: 类别=3, 范围=[278, 278], 样本数=1
# 块 217: 类别=4, 范围=[279, 279], 样本数=1
# 块 218: 类别=3, 范围=[280, 280], 样本数=1
# 块 219: 类别=4, 范围=[281, 281], 样本数=1
# 块 220: 类别=3, 范围=[282, 283], 样本数=2
# 块 221: 类别=4, 范围=[284, 284], 样本数=1
# 块 222: 类别=3, 范围=[285, 285], 样本数=1
# 块 223: 类别=2, 范围=[286, 286], 样本数=1
# 块 224: 类别=4, 范围=[287, 287], 样本数=1
# 块 225: 类别=1, 范围=[288, 288], 样本数=1
# 块 226: 类别=2, 范围=[289, 289], 样本数=1
# 块 227: 类别=3, 范围=[290, 290], 样本数=1
# 块 228: 类别=1, 范围=[291, 293], 样本数=3
# 块 229: 类别=2, 范围=[294, 294], 样本数=1
# 块 230: 类别=4, 范围=[295, 295], 样本数=1
# 块 231: 类别=2, 范围=[296, 298], 样本数=3
# 块 232: 类别=1, 范围=[299, 299], 样本数=1
# 块 233: 类别=3, 范围=[300, 301], 样本数=2
# 块 234: 类别=2, 范围=[302, 302], 样本数=1
# 块 235: 类别=1, 范围=[303, 303], 样本数=1
# 块 236: 类别=4, 范围=[304, 304], 样本数=1
# 块 237: 类别=3, 范围=[305, 305], 样本数=1
# 块 238: 类别=2, 范围=[306, 306], 样本数=1
# 块 239: 类别=3, 范围=[307, 307], 样本数=1
# 块 240: 类别=2, 范围=[308, 309], 样本数=2
# 块 241: 类别=1, 范围=[310, 311], 样本数=2
# 块 242: 类别=4, 范围=[312, 314], 样本数=3
# 块 243: 类别=1, 范围=[315, 315], 样本数=1
# 块 244: 类别=4, 范围=[316, 316], 样本数=1
# 块 245: 类别=1, 范围=[317, 317], 样本数=1
# 块 246: 类别=2, 范围=[318, 318], 样本数=1
# 块 247: 类别=4, 范围=[319, 319], 样本数=1
# 块 248: 类别=1, 范围=[320, 320], 样本数=1
# 块 249: 类别=2, 范围=[321, 321], 样本数=1
# 块 250: 类别=1, 范围=[322, 322], 样本数=1
# 块 251: 类别=2, 范围=[323, 324], 样本数=2
# 块 252: 类别=1, 范围=[325, 325], 样本数=1
# 块 253: 类别=4, 范围=[326, 326], 样本数=1
# 块 254: 类别=1, 范围=[327, 329], 样本数=3
# 块 255: 类别=4, 范围=[330, 330], 样本数=1
# 块 256: 类别=1, 范围=[331, 331], 样本数=1
# 块 257: 类别=2, 范围=[332, 332], 样本数=1
# 块 258: 类别=3, 范围=[333, 333], 样本数=1
# 块 259: 类别=1, 范围=[334, 334], 样本数=1
# 块 260: 类别=4, 范围=[335, 335], 样本数=1
# 块 261: 类别=1, 范围=[336, 338], 样本数=3
# 块 262: 类别=4, 范围=[339, 339], 样本数=1
# 块 263: 类别=2, 范围=[340, 340], 样本数=1
# 块 264: 类别=1, 范围=[341, 341], 样本数=1
# 块 265: 类别=3, 范围=[342, 343], 样本数=2
# 块 266: 类别=1, 范围=[344, 345], 样本数=2
# 块 267: 类别=4, 范围=[346, 346], 样本数=1
# 块 268: 类别=1, 范围=[347, 348], 样本数=2
# 块 269: 类别=2, 范围=[349, 349], 样本数=1
# 块 270: 类别=4, 范围=[350, 350], 样本数=1
# 块 271: 类别=1, 范围=[351, 351], 样本数=1
# 块 272: 类别=4, 范围=[352, 352], 样本数=1
# 块 273: 类别=2, 范围=[353, 353], 样本数=1
# 块 274: 类别=1, 范围=[354, 355], 样本数=2
# 块 275: 类别=3, 范围=[356, 356], 样本数=1
# 块 276: 类别=1, 范围=[357, 357], 样本数=1
# 块 277: 类别=4, 范围=[358, 358], 样本数=1
# 块 278: 类别=1, 范围=[359, 359], 样本数=1
# 块 279: 类别=2, 范围=[360, 360], 样本数=1
# 块 280: 类别=3, 范围=[361, 362], 样本数=2
# 块 281: 类别=1, 范围=[363, 363], 样本数=1
# 块 282: 类别=4, 范围=[364, 365], 样本数=2
# 块 283: 类别=3, 范围=[366, 366], 样本数=1
# 块 284: 类别=4, 范围=[367, 367], 样本数=1
# 块 285: 类别=2, 范围=[368, 368], 样本数=1
# 块 286: 类别=1, 范围=[369, 369], 样本数=1
# 块 287: 类别=4, 范围=[370, 371], 样本数=2
# 块 288: 类别=3, 范围=[372, 372], 样本数=1
# 块 289: 类别=2, 范围=[373, 373], 样本数=1
# 块 290: 类别=3, 范围=[374, 375], 样本数=2
# 块 291: 类别=2, 范围=[376, 377], 样本数=2
# 块 292: 类别=1, 范围=[378, 378], 样本数=1
# 块 293: 类别=3, 范围=[379, 380], 样本数=2
# 块 294: 类别=2, 范围=[381, 382], 样本数=2
# 块 295: 类别=1, 范围=[383, 384], 样本数=2
# 块 296: 类别=2, 范围=[385, 389], 样本数=5
# 块 297: 类别=4, 范围=[390, 390], 样本数=1
# 块 298: 类别=2, 范围=[391, 391], 样本数=1
# 块 299: 类别=1, 范围=[392, 393], 样本数=2
# 块 300: 类别=2, 范围=[394, 395], 样本数=2
# 块 301: 类别=3, 范围=[396, 396], 样本数=1
# 块 302: 类别=1, 范围=[397, 397], 样本数=1
# 块 303: 类别=3, 范围=[398, 399], 样本数=2
# 块 304: 类别=4, 范围=[400, 400], 样本数=1
# 块 305: 类别=3, 范围=[401, 403], 样本数=3
# 块 306: 类别=1, 范围=[404, 404], 样本数=1
# 块 307: 类别=3, 范围=[405, 406], 样本数=2
# 块 308: 类别=4, 范围=[407, 409], 样本数=3
# 块 309: 类别=1, 范围=[410, 410], 样本数=1
# 块 310: 类别=2, 范围=[411, 411], 样本数=1
# 块 311: 类别=4, 范围=[412, 413], 样本数=2
# 块 312: 类别=2, 范围=[414, 415], 样本数=2
# 块 313: 类别=1, 范围=[416, 417], 样本数=2
# 块 314: 类别=3, 范围=[418, 419], 样本数=2
# 块 315: 类别=2, 范围=[420, 420], 样本数=1
# 块 316: 类别=1, 范围=[421, 422], 样本数=2
# 块 317: 类别=2, 范围=[423, 425], 样本数=3
# 块 318: 类别=1, 范围=[426, 426], 样本数=1
# 块 319: 类别=3, 范围=[427, 427], 样本数=1
# 块 320: 类别=1, 范围=[428, 428], 样本数=1
# 块 321: 类别=2, 范围=[429, 429], 样本数=1
# 块 322: 类别=4, 范围=[430, 432], 样本数=3
# 块 323: 类别=3, 范围=[433, 435], 样本数=3
# 块 324: 类别=1, 范围=[436, 437], 样本数=2
# 块 325: 类别=2, 范围=[438, 438], 样本数=1
# 块 326: 类别=3, 范围=[439, 439], 样本数=1
# 块 327: 类别=1, 范围=[440, 441], 样本数=2
# 块 328: 类别=2, 范围=[442, 442], 样本数=1
# 块 329: 类别=1, 范围=[443, 443], 样本数=1
# 块 330: 类别=3, 范围=[444, 444], 样本数=1
# 块 331: 类别=4, 范围=[445, 445], 样本数=1
# 块 332: 类别=3, 范围=[446, 446], 样本数=1
# 块 333: 类别=4, 范围=[447, 447], 样本数=1
# 块 334: 类别=1, 范围=[448, 448], 样本数=1
# 块 335: 类别=2, 范围=[449, 449], 样本数=1
# 块 336: 类别=1, 范围=[450, 450], 样本数=1
# 块 337: 类别=2, 范围=[451, 452], 样本数=2
# 块 338: 类别=3, 范围=[453, 453], 样本数=1
# 块 339: 类别=4, 范围=[454, 454], 样本数=1
# 块 340: 类别=3, 范围=[455, 455], 样本数=1
# 块 341: 类别=1, 范围=[456, 456], 样本数=1
# 块 342: 类别=2, 范围=[457, 457], 样本数=1
# 块 343: 类别=4, 范围=[458, 460], 样本数=3
# 块 344: 类别=2, 范围=[461, 462], 样本数=2
# 块 345: 类别=3, 范围=[463, 463], 样本数=1
# 块 346: 类别=2, 范围=[464, 464], 样本数=1
# 块 347: 类别=3, 范围=[465, 465], 样本数=1
# 块 348: 类别=1, 范围=[466, 467], 样本数=2
# 块 349: 类别=2, 范围=[468, 469], 样本数=2
# 块 350: 类别=4, 范围=[470, 471], 样本数=2
# 块 351: 类别=3, 范围=[472, 473], 样本数=2
# 块 352: 类别=2, 范围=[474, 474], 样本数=1
# 块 353: 类别=1, 范围=[475, 476], 样本数=2
# 块 354: 类别=2, 范围=[477, 477], 样本数=1
# 块 355: 类别=3, 范围=[478, 478], 样本数=1
# 块 356: 类别=2, 范围=[479, 479], 样本数=1
#
# 是否按类别分块排序：否
# 提示：存在类别在多个块中出现（非连续分块）
